# %% [markdown]
# # Prediction Using Decision tree classifier
#
# ## Task- Create a classifier and visualize it graphically
#
# ## Submitted By:- Tarun Lathiya

# %%
# installing all modules which required for the task
import numpy as n
import pandas as p
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# ## Load data

# %%
df = p.read_csv('Iris.csv',index_col='Id')

# %% [markdown]
# ## Examine the data

# %%
df.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
# Extracting variables
X = df.iloc[:,[0,1,2,3]].values
# print(X)

# %%
y = df.iloc[:,4].values
# print(y)

# %% [markdown]
# ## Data visualization

# %%
sb.barplot(x=df['Species'],y=df['SepalLengthCm'],data=df)

# %%
sb.barplot(x=df['Species'],y=df['SepalWidthCm'],data=df)

# %%
sb.barplot(x=df['Species'],y=df['PetalLengthCm'],data=df)

# %%
sb.barplot(x=df['Species'],y=df['PetalWidthCm'],data=df)

# %%
sb.pairplot(df)

# %% [markdown]
# ## Building classifier

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier
claf = DecisionTreeClassifier()
claf.fit(X_train,y_train)
print("Trining Complete")
# Out:
# Trining Complete

# %%
# displaying text presentation of classifier
from sklearn import tree
txt_rep = tree.export_text(claf)
print(txt_rep)
# Out:
# |--- feature_2 <= 2.35
# |   |--- class: Iris-setosa
# |--- feature_2 >  2.35
# |   |--- feature_3 <= 1.75
# |   |   |--- feature_2 <= 4.95
# |   |   |   |--- feature_3 <= 1.65
# |   |   |   |   |--- class: Iris-versicolor
# |   |   |   |--- feature_3 >  1.65
# |   |   |   |   |--- class: Iris-virginica
# |   |   |--- feature_2 >  4.95
# |   |   |   |--- feature_3 <= 1.55
# |   |   |   |   |--- class: Iris-virginica
# |   |   |   |--- feature_3 >  1.55
# |   |   |   |   |--- feature_2 <= 5.45
# |   |   |   |   |   |--- class: Iris-versicolor
# |   |   |   |   |--- feature_2 >  5.45
# |   |   |   |   |   |--- class: Iris-virginica
# |   |--- feature_3 >  1.75
# |   |   |--- feature_2 <= 4.85
# |   |   |   |--- feature_0 <= 5.95
# |   |   |   |   |--- class: Iris-versicolor
# |   |   |   |--- feature_0 >  5.95
# |   |   |   |   |--- class: Iris-virginica
# |   |   |--- feature_2 >  4.85
# |   |   |   |--- class: Iris-virginica

# %% [markdown]
# ## Tree visualization

# %%
# visualizing the tree 
fig = plt.figure(figsize=(30,25))
fig = tree.plot_tree(claf, feature_names=X, class_names=y, filled=True, rounded=True)

# %% [markdown]
# # Test the model

# %%
y_pred = claf.predict(X_test)

# %%
a = [4,3,1,1]
test = n.array([a])
prediction = claf.predict(test)
print(prediction)
# Out:
# ['Iris-setosa']

# %%
b = [7,3,5,0]
test2 = n.array([b])
pred = claf.predict(test2)
print(pred)
# Out:
# ['Iris-virginica']
